# %% [markdown]
# ## Common DEGs between Idiopathic Portal Hypertension and Covid Patients

# %%
import numpy as np
import pandas as pd

# %%
df_IPH_down = pd.read_excel('idiopathicPortalHypertensionIPH_DEG.xlsx',sheet_name='downRegulated')

# %%
df_IPH_down.head(2)
# Out:
#    Unnamed: 0       ID  adj.P.Val   P.Value     t    B  logFC Gene.symbol  \
# 0           0  8069340      0.888  0.004212 -4.16 -4.3  -1.03        YBEY
# 1           1  7972682      0.888  0.004472 -4.11 -4.3  -1.20      KDELC1
#
#                          Gene.title  absolute_logFC
# 0  ybeY metallopeptidase (putative)            1.03
# 1           KDEL motif containing 1            1.20

# %%
df_IPH_down.shape
# Out:
# (32, 10)

# %%
df_IPH_up = pd.read_excel('idiopathicPortalHypertensionIPH_DEG.xlsx',sheet_name='upRegulated')

# %%
df_IPH_up.head(2)
# Out:
#    Unnamed: 0       ID  adj.P.Val   P.Value     t    B  logFC Gene.symbol  \
# 0           0  8149116      0.888  0.000168  7.24 -4.2   2.94      DEFA1B
# 1           1  8149126      0.888  0.000168  7.24 -4.2   2.94       DEFA3
#
#                                           Gene.title  absolute_logFC
# 0  defensin alpha 1B///defensin alpha 3///defensi...            2.94
# 1  defensin alpha 1B///defensin alpha 3///defensi...            2.94

# %%
df_IPH_up.shape
# Out:
# (239, 10)

# %%
df_covid_down = pd.read_excel('covidDEGs.xlsx',sheet_name='downRegulated')

# %%
df_covid_down.head(2)
# Out:
#    Unnamed: 0  index                 Gid GENE_SYMBOL  CPM-N1  CPM-N2  CPM-N3  \
# 0           0      0  ENSG00000134184.13       GSTM1    7.34    4.62    6.22
# 1           1      2   ENSG00000233392.5    AC104809   13.87    5.25   11.97
#
#    CPM-P1  CPM-P2  CPM-P3  baseMean  log2FoldChange  abslFC  lfcSE   stat  \
# 0    0.07    0.21    0.21    290.84           -5.01    5.01   0.36 -13.82
# 1    0.02    0.26    0.09    462.90           -6.13    6.13   0.60 -10.27
#
#          pvalue          padj     log10P   Tag
# 0  1.920000e-43  5.440000e-39  38.264401  Down
# 1  9.900000e-25  9.360000e-21  20.028724  Down

# %%
df_covid_down.shape
# Out:
# (599, 19)

# %%
df_covid_up = pd.read_excel('covidDEGs.xlsx',sheet_name='upRegulated')

# %%
df_covid_up.head(2)
# Out:
#    Unnamed: 0  index                 Gid GENE_SYMBOL  CPM-N1  CPM-N2  CPM-N3  \
# 0           0      1   ENSG00000211934.3       IGHV1    0.46    0.25    0.36
# 1           1      3  ENSG00000198848.12        CES1    3.84    0.83    4.96
#
#    CPM-P1  CPM-P2  CPM-P3  baseMean  log2FoldChange  abslFC  lfcSE   stat  \
# 0    5.14   20.56   63.93   1361.64            6.36    6.36   0.60  10.51
# 1  185.00   76.06  398.24  12508.37            6.53    6.53   0.65  10.12
#
#          pvalue          padj     log10P Tag
# 0  7.580000e-26  1.070000e-21  20.970616  Up
# 1  4.690000e-24  3.330000e-20  19.477556  Up

# %%
df_covid_up.shape
# Out:
# (1146, 19)

# %%
df_IPH_covid_down = pd.merge(df_IPH_down,df_covid_down,how='inner',left_on='Gene.symbol',right_on='GENE_SYMBOL')

# %%
df_IPH_covid_up = pd.merge(df_IPH_up,df_covid_up,how='inner',left_on='Gene.symbol',right_on='GENE_SYMBOL')

# %%
df_IPH_covid_down
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0_x, ID, adj.P.Val, P.Value, t, B, logFC, Gene.symbol, Gene.title, absolute_logFC, Unnamed: 0_y, index, Gid, GENE_SYMBOL, CPM-N1, CPM-N2, CPM-N3, CPM-P1, CPM-P2, CPM-P3, baseMean, log2FoldChange, abslFC, lfcSE, stat, pvalue, padj, log10P, Tag]
# Index: []
#
# [0 rows x 29 columns]

# %%
#df_PAH_covid_down[['GeneName','GENE_SYMBOL']]

# %%
#df_PAH_covid_down['GeneName'].nunique()

# %%
#df_PAH_covid_down['GeneName'].unique()

# %%
df_IPH_covid_up
# Out:
#     Unnamed: 0_x       ID  adj.P.Val   P.Value     t     B  logFC Gene.symbol  \
# 0              4  7979307      0.888  0.000789  5.62 -4.24   1.79      DLGAP5
# 1             18  7982757      0.888  0.003215  4.38 -4.29   1.00        KNL1
# 2             29  8014974      0.888  0.005491  3.95 -4.31   1.56       TOP2A
# 3             64  7909708      0.888  0.010295  3.47 -4.34   1.03       CENPF
# 4             67  8043360      0.888  0.010576  3.45 -4.34   1.37        IGKC
# 5             72  8043433      0.888  0.011775  3.38 -4.35   1.32        IGKC
# 6             96  8043449      0.888  0.015182  3.19 -4.36   1.33        IGKC
# 7            109  8043438      0.888  0.020238  2.99 -4.38   1.23        IGKC
# 8            115  8053713      0.888  0.021617  2.94 -4.38   1.22        IGKC
# 9            192  8043436      0.888  0.042701  2.47 -4.43   1.06        IGKC
# 10            76  8129763      0.888  0.012579  3.33 -4.35   1.24       MTFR2
# ...

# %%
df_IPH_covid_up[['Gene.symbol','GENE_SYMBOL']]
# Out:
#    Gene.symbol GENE_SYMBOL
# 0       DLGAP5      DLGAP5
# 1         KNL1        KNL1
# 2        TOP2A       TOP2A
# 3        CENPF       CENPF
# 4         IGKC        IGKC
# 5         IGKC        IGKC
# 6         IGKC        IGKC
# 7         IGKC        IGKC
# 8         IGKC        IGKC
# 9         IGKC        IGKC
# 10       MTFR2       MTFR2
# 11        EAF2        EAF2
# 12      PAPSS1      PAPSS1
# 13      HAVCR2      HAVCR2
# 14       PRDM1       PRDM1
# 15        EZH2        EZH2
# 16       MKI67       MKI67
# 17       CD180       CD180
# 18    RAD51AP1    RAD51AP1
# 19    HIST1H4H    HIST1H4H
# 20       IGHA2       IGHA2
# 21       IGHA2       IGHA2
# 22       IGHA1       IGHA1
# 23       ADAP2       ADAP2
# 24         BTK         BTK

# %%
df_IPH_covid_up['Gene.symbol'].nunique()
# Out:
# 19

# %%
df_IPH_covid_up['Gene.symbol'].unique()
# Out:
# array(['DLGAP5', 'KNL1', 'TOP2A', 'CENPF', 'IGKC', 'MTFR2', 'EAF2',
#        'PAPSS1', 'HAVCR2', 'PRDM1', 'EZH2', 'MKI67', 'CD180', 'RAD51AP1',
#        'HIST1H4H', 'IGHA2', 'IGHA1', 'ADAP2', 'BTK'], dtype=object)

# %%
df_output_down = df_IPH_covid_down['GENE_SYMBOL']

# %%
df_output_up = df_IPH_covid_up['GENE_SYMBOL']

# %%
df_output_all = pd.merge(df_IPH_covid_down,df_IPH_covid_up,how='outer')

# %%
df_output_all.head(2)
# Out:
#    Unnamed: 0_x       ID  adj.P.Val   P.Value     t     B  logFC Gene.symbol  \
# 0             4  7979307      0.888  0.000789  5.62 -4.24   1.79      DLGAP5
# 1            18  7982757      0.888  0.003215  4.38 -4.29   1.00        KNL1
#
#                  Gene.title  absolute_logFC  ...  CPM-P3  baseMean  \
# 0  DLG associated protein 5            1.79  ...    4.75    195.01
# 1    kinetochore scaffold 1            1.00  ...    7.56    396.16
#
#   log2FoldChange abslFC  lfcSE  stat        pvalue          padj     log10P  \
# 0           3.47   3.47   0.40  8.67  4.360000e-18  1.030000e-14  13.987163
# 1           1.81   1.81   0.37  4.88  1.080000e-06  8.230000e-05   4.084600
#
#    Tag
# 0   Up
# 1   Up
#
# [2 rows x 29 columns]

# %%
df_all = df_output_all[['P.Value','logFC','Gene.symbol']]

# %%
writer = pd.ExcelWriter('covidIPH_commonDEGs.xlsx',engine='xlsxwriter')

# %%
writerPvalLogfc = pd.ExcelWriter('IPH_covid_all.xlsx',engine='xlsxwriter')

# %%
df_output_down.to_excel(writer,sheet_name='downRegulated')

# %%
df_output_up.to_excel(writer,sheet_name='upRegulated')

# %%
df_all.to_excel(writerPvalLogfc)

# %%
writer.save()
writer.close()
writerPvalLogfc.save()
writerPvalLogfc.close()
